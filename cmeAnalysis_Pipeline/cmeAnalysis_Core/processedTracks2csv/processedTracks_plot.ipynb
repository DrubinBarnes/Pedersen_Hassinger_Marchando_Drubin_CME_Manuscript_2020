# %%
# by Joh Schöneberg

# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('processedTracks.csv')


trackId = 3
A = data[data['trackId'] == trackId]['A'].astype(float)

plt.plot(A)

# %%
data
# Out:
#        trackId  length     t     f              x              y  \
# 0            1     241     0     1   7.079495e+01   2.612428e+01
# 1            1     241     1     2   7.007760e+01   2.586967e+01
# 2            1     241     2     3   7.079495e+01   2.612428e+01
# 3            1     241     3     4   7.053484e+01   2.618375e+01
# 4            1     241     4     5   7.053484e+01   2.618375e+01
# 5            1     241     5     6   7.019629e+01   2.701883e+01
# 6            1     241     6     7   7.045242e+01   2.620229e+01
# 7            1     241     7     8   7.045242e+01   2.620229e+01
# 8            1     241     8     9   7.271544e+01   2.521162e+01
# 9            1     241     9    10   7.043312e+01   2.608946e+01
# 10           1     241    10    11   7.043312e+01   2.608946e+01
# 11           1     241    11    12   7.043312e+01   2.608946e+01
# 12           1     241    12    13   7.071280e+01   2.579885e+01
# ...
